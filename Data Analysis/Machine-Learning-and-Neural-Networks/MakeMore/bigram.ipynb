# %%
words = open("names.txt", 'r').read().split()
words[:10]
# Out:
# ['emma',
#  'olivia',
#  'ava',
#  'isabella',
#  'sophia',
#  'charlotte',
#  'mia',
#  'amelia',
#  'harper',
#  'evelyn']

# %%
len(words)
min(len(w) for w in words)
max(len(w) for w in words)
# Out:
# 15

# %%
b = {} # create a dict to store how often a pair of characters occur

for w in words:
    chs = ['<S>'] + list(w) + ['<E>']
    for ch1, ch2 in zip(chs, chs[1:]): # Creating two consecutive characters
        biagram = (ch1, ch2)
        b[biagram] = b.get(biagram, 0) + 1 # If biagram exists, return its count else return 0 and add the biagram

# %%
sorted(b.items(), key = lambda kv: -kv[1])m, a
# Out:
#   Cell In[6], line 1
#     sorted(b.items(), key = lambda kv: -kv[1])m, a
#                                               ^
# SyntaxError: invalid syntax

# %%
# It is better to store this data in a 28 x 28 torch
import torch

N = torch.zeros((28, 28), dtype = torch.int32)

# Create a map of a - z = 0 - 25 including <s> and <e>
chars = sorted(set(''.join(words))) # Set throws out duplicate charaters
stoi = {c:i for i,c in enumerate(chars)} # It stores indexes to a specific chars now for out 28x28 tensor
stoi['<S>'] = 26
stoi['<E>'] = 27

# %%
b = {} # create a dict to store how often a pair of characters occur

for w in words:
    chs = ['<S>'] + list(w) + ['<E>']
    for ch1, ch2 in zip(chs, chs[1:]): # Creating two consecutive characters
        ix1 = stoi[ch1] # First index
        ix2 = stoi[ch2] # Second indec
        N[ix1, ix2] += 1

# %%
itos = {i:s for s,i in stoi.items()}
import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure(figsize=(16,16))
plt.imshow(N, cmap='Blues')
for i in range(28):
    for j in range(28):
        chstr = itos[i] + itos[j]
        plt.text(j, i, chstr, ha="center", va="bottom", color='gray')
        plt.text(j, i, N[i, j].item(), ha="center", va="top", color='gray')
plt.axis('off');
