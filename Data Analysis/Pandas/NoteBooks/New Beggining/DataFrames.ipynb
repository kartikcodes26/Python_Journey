# %%
import pandas as pd 
import numpy as np

# %%
data = {
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]
}

# %%
df = pd.DataFrame(data)

# %%
print(df)
# Out:
#    calories  duration
# 0       420        50
# 1       380        40
# 2       390        45

# %%
print(df.loc[0]) # Use when searching by index
# Out:
# calories    420
# duration     50
# Name: 0, dtype: int64

# %%
print(df.iloc[1,1])  # Use when accessing by standard notation (row, column)
# Out:
# 40

# %%
df2 = pd.DataFrame(data, index=["Day 1", "Day 2", "Day 2"])  # Custom index

# %%
print(df2)
# Out:
#        calories  duration
# Day 1       420        50
# Day 2       380        40
# Day 2       390        45

# %%
print(df2["calories"])  # Search by column
# Out:
# Day 1    420
# Day 2    380
# Day 2    390
# Name: calories, dtype: int64

# %%
df.head(10) # 10 rows from top
# Out:
#    calories  duration
# 0       420        50
# 1       380        40
# 2       390        45
