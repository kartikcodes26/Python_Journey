# %%
import pandas as pd 
import numpy as np

# %%
dataset = {
    'English': [12, 14, 17, 11, 19, 16],
    'Maths' : [11, 17, 20, 10, 16, 16],
    'Science' : [14, 9, 10, 15, 17, 12]
}

# %%
df = pd.DataFrame(dataset)

# %%
print(dataset)
# Out:
# {'English': [12, 14, 17, 11, 19, 16], 'Maths': [11, 17, 20, 10, 16, 16], 'Science': [14, 9, 10, 15, 17, 12]}

# %%
mydataset = {
  'cars': ["BMW", "Volvo", "Ford"],
  'passings': [3, 7, 2],
  'Cost' : [34, 67, 46]
}

myvar = pd.DataFrame(mydataset)

print(myvar)
# Out:
#     cars  passings  Cost
# 0    BMW         3    34
# 1  Volvo         7    67
# 2   Ford         2    46

# %%
print(pd.__version__)
# Out:
# 2.2.3
