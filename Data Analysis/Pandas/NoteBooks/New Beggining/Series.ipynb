# %%
import pandas as pd 
import numpy as np

# %%
s = [2, 4, 8]

# %%
ser = pd.Series(s)

# %%
ser
# Out:
# 0    2
# 1    4
# 2    8
# dtype: int64

# %%
print(ser[2])
# Out:
# 8

# %%
ser2 = pd.Series(s, index = ['x', 'y', 'z'])

# %%
print(ser2)
# Out:
# x    2
# y    4
# z    8
# dtype: int64

# %%
print(ser2['y'])
# Out:
# 4

# %%
calories = {
            "day1": 420, 
            "day2": 380, 
            "day3": 390
}

# %%
cal_series = pd.Series(calories)

# %%
print(cal_series)
# Out:
# day1    420
# day2    380
# day3    390
# dtype: int64

# %%
cal_series2 = pd.Series(calories, index = ['day1', 'day2'])

# %%
print(cal_series2)
# Out:
# day1    420
# day2    380
# dtype: int64
