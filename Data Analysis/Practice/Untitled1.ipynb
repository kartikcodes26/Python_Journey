# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
import pandas as pd

data = {
    'EmployeeID': range(1001, 1021),
    'Name': ['Aisha Khan', 'Rohan Mehta', 'Priya Sharma', 'David Chen', 'Sarah Johnson',
              'Vikram Patel', 'Emily Davis', 'Arjun Nair', 'Laura Wilson', 'Karan Malhotra',
              'Neha Gupta', 'James Miller', 'Ananya Iyer', 'Michael Brown', 'Riya Kapoor',
              'Chris Taylor', 'Sneha Reddy', 'Daniel Lee', 'Pooja Verma', 'Robert Garcia'],
    'Department': ['Engineering', 'Sales', 'Marketing', 'Engineering', 'HR',
                   'Finance', 'Engineering', 'Sales', 'Marketing', 'Engineering',
                   'Finance', 'HR', 'Engineering', 'Sales', 'Marketing',
                   'Engineering', 'Finance', 'HR', 'Engineering', 'Sales'],
    'JobTitle': ['Software Engineer', 'Sales Manager', 'Marketing Specialist', 'Senior Engineer', 'HR Coordinator',
                 'Financial Analyst', 'Data Scientist', 'Account Executive', 'Content Strategist', 'Engineering Manager',
                 'Finance Manager', 'HR Manager', 'DevOps Engineer', 'Sales Director', 'Marketing Manager',
                 'Frontend Developer', 'Financial Controller', 'Recruiter', 'Backend Developer', 'Sales Rep'],
    'Salary': [95000, 88000, 72000, 125000, 65000,
               78000, 110000, 82000, 70000, 145000,
               115000, 90000, 105000, 135000, 98000,
               92000, 120000, 68000, 108000, 75000],
    'HireDate': pd.to_datetime(['2019-03-15', '2017-06-01', '2020-01-10', '2015-09-23', '2021-02-14',
                                  '2018-11-30', '2016-07-19', '2022-04-05', '2019-08-12', '2013-05-20',
                                  '2017-01-25', '2020-06-18', '2018-03-09', '2012-10-01', '2019-11-22',
                                  '2021-07-07', '2014-02-28', '2022-09-15', '2020-12-03', '2023-01-16']),
    'Location': ['New York', 'Chicago', 'Los Angeles', 'New York', 'Austin',
                 'Chicago', 'Seattle', 'New York', 'Los Angeles', 'Seattle',
                 'Austin', 'Chicago', 'Seattle', 'New York', 'Los Angeles',
                 'Seattle', 'Austin', 'Chicago', 'New York', 'Los Angeles'],
    'ManagerID': [1010, 1014, 1015, 1010, 1012,
                  1017, 1010, 1014, 1015, None,
                  1017, None, 1010, None, 1015,
                  1010, 1017, 1012, 1010, 1014]
}

df = pd.DataFrame(data)
df.head()
# Out:
#    EmployeeID           Name   Department              JobTitle  Salary  \
# 0        1001     Aisha Khan  Engineering     Software Engineer   95000
# 1        1002    Rohan Mehta        Sales         Sales Manager   88000
# 2        1003   Priya Sharma    Marketing  Marketing Specialist   72000
# 3        1004     David Chen  Engineering       Senior Engineer  125000
# 4        1005  Sarah Johnson           HR        HR Coordinator   65000
#
#     HireDate     Location  ManagerID
# 0 2019-03-15     New York     1010.0
# 1 2017-06-01      Chicago     1014.0
# 2 2020-01-10  Los Angeles     1015.0
# 3 2015-09-23     New York     1010.0
# 4 2021-02-14       Austin     1012.0

# %%
df.groupby("Department")["Location"].value_counts()
# Out:
# Department   Location
# Engineering  Seattle        4
#              New York       3
# Finance      Austin         2
#              Chicago        1
# HR           Chicago        2
#              Austin         1
# Marketing    Los Angeles    3
# Sales        New York       2
#              Chicago        1
#              Los Angeles    1
# Name: count, dtype: int64
