# %%
# Generating normally distributed data
x = np.random.normal(mean = 2, std = 4, size = 90)

# Exponentially distributed statistic
x = np.random.exponential(scale = 50, size = 10_000)
# creates a simulated population of 100,000 exponentially distributed values with an average (mean) of 50.

# %%
# n_bootstrap = how many means we want (Kitni baar resample karke mean store kare)
# any data can be selected twice, thrice....

# Bootstrapping
def sample_means(sample, n_bootstrap = 1000):
    means = []
    for _ in range(n_bootstrap):
        temp = np.random.choice(
            population,
            size = len(sample),
            replace = True
        )
        means.append(temp.mean())

    return means

# Higher the sample size more bell shaped the curve will be (Central limit theorem)

# %%
lower = np.percentile(m_sample, 5)
higher = np.percentile(m_sample, 95)

print(f"We have 90% confidence that the true mean lies between {lower} to {higher}")

# %%
68, 95, 99.7 rule

68% of the data are within 1sd
95% of the data are within 2sd
99.7% of the data are within 3sd
