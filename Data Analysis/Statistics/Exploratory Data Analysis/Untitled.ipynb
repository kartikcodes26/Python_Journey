# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.DataFrame({
    "City": [
        "Mumbai","Mumbai","Mumbai","Mumbai","Mumbai","Mumbai","Mumbai","Mumbai",
        "Delhi","Delhi","Delhi","Delhi","Delhi","Delhi","Delhi","Delhi",
        "Pune","Pune","Pune","Pune","Pune","Pune","Pune","Pune",
        "Bangalore","Bangalore","Bangalore",
        "Hyderabad","Hyderabad","Hyderabad"
    ],

    "Area": [
        800,950,1100,1250,1400,1600,1800,2100,
        850,1000,1150,1300,1450,1700,1900,2200,
        750,900,1050,1200,1350,1500,1700,2000,
        950,1400,1800,
        1000,1500,2100
    ],

    "Price": [
        95,110,125,145,165,190,220,270,
        80,98,115,135,150,180,205,240,
        70,85,100,118,135,155,180,215,
        120,185,250,
        105,175,245
    ],

    "Bedrooms": [
        2,2,3,3,3,4,4,5,
        2,2,3,3,3,4,4,5,
        1,2,2,3,3,3,4,4,
        2,3,4,
        2,3,5
    ]
})

df.head()
# Out:
#      City  Area  Price  Bedrooms
# 0  Mumbai   800     95         2
# 1  Mumbai   950    110         2
# 2  Mumbai  1100    125         3
# 3  Mumbai  1250    145         3
# 4  Mumbai  1400    165         3

# %%
sns.relplot(
    data = df,
    x = "Area",
    y = "Price",
    hue = "City",
    kind = "line",
    marker = "o"
)

plt.show()

# %%
sns.relplot(
    data = df,
    col="City",
    x = "Area",
    y = "Price",
    hue = "City",
    kind = "line",
    marker = "o"
)

plt.show()
